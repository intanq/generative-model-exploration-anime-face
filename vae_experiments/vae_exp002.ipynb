# %%
expID='vae_exp002'

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor, Normalize
from torchvision.utils import save_image
import os

# Set device (GPU if available, otherwise CPU)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
torch.cuda.empty_cache()

# %%
import matplotlib.pyplot as plt
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils as vutils
import numpy as np

# %% [markdown]
# # Define Constants

# %%
# Hyperparameters
image_size = 64
latent_dim = 100
hidden_dim = 256
batch_size = 64
epochs = 50
learning_rate = 1e-3
dataroot = 'data/'
ngpu = 1

# Create directory to save generated images
os.makedirs(f'vae_generated_images/{expID}', exist_ok=True)

# %% [markdown]
# # Data Preparation

# %%
# Create the dataset
dataset = dset.ImageFolder(root=dataroot,
                           transform=transforms.Compose([
                               transforms.Resize(image_size),
                               transforms.CenterCrop(image_size),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                           ]))

# %%
# Create the dataloader
dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                         shuffle=True, num_workers=2)

# %%
# Decide which device we want to run on
device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")

# %%
# Plot some training images
real_batch = next(iter(dataloader))
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %% [markdown]
# # Implementation

# %% [markdown]
# ## Encoder Model

# %%
class Encoder(nn.Module):
    def __init__(self, latent_dim):
        super(Encoder, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(3, 32, 4, 2, 1),   # input shape: 3 x 64 x 64, output shape: 32 x 32 x 32
            nn.ReLU(),
            nn.Conv2d(32, 64, 4, 2, 1),  # input shape: 32 x 32 x 32, output shape: 64 x 16 x 16
            nn.ReLU(),
            nn.Conv2d(64, 128, 4, 2, 1), # input shape: 64 x 16 x 16, output shape: 128 x 8 x 8
            nn.ReLU(),
            nn.Conv2d(128, 256, 4, 2, 1),# input shape: 128 x 8 x 8, output shape: 256 x 4 x 4
            nn.ReLU()
        )
        self.fc_mu = nn.Linear(256 * 4 * 4, latent_dim)
        self.fc_logvar = nn.Linear(256 * 4 * 4, latent_dim)

    def forward(self, x):
        x = self.conv(x)
        x = x.view(x.size(0), -1)
        mu = self.fc_mu(x)
        logvar = self.fc_logvar(x)
        return mu, logvar

# %% [markdown]
# ## Decoder Model

# %%
class Decoder(nn.Module):
    def __init__(self, latent_dim):
        super(Decoder, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(latent_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 256 * 4 * 4),
            nn.ReLU()
        )
        self.deconv = nn.Sequential(
            nn.ConvTranspose2d(256, 128, 4, 2, 1),  # input shape: 256 x 4 x 4, output shape: 128 x 8 x 8
            nn.ReLU(),
            nn.ConvTranspose2d(128, 64, 4, 2, 1),   # input shape: 128 x 8 x 8, output shape: 64 x 16 x 16
            nn.ReLU(),
            nn.ConvTranspose2d(64, 32, 4, 2, 1),    # input shape: 64 x 16 x 16, output shape: 32 x 32 x 32
            nn.ReLU(),
            nn.ConvTranspose2d(32, 3, 4, 2, 1),     # input shape: 32 x 32 x 32, output shape: 3 x 64 x 64
            nn.Tanh()
        )
        
    def forward(self, z):
        x = self.fc(z)
        x = x.view(x.size(0), 256, 4, 4)
        x = self.deconv(x)
        return x

# %% [markdown]
# ## VAE Model

# %%
class VAE(nn.Module):
    def __init__(self, latent_dim):
        super(VAE, self).__init__()
        self.encoder = Encoder(latent_dim)
        self.decoder = Decoder(latent_dim)

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        z = mu + eps * std
        return z

    def forward(self, x):
        mu, logvar = self.encoder(x)
        z = self.reparameterize(mu, logvar)
        reconstructed_x = self.decoder(z)
        return reconstructed_x, mu, logvar

# %%
# Loss function
# def loss_function(reconstructed_x, x, mu, logvar):
#     BCE = nn.functional.binary_cross_entropy(reconstructed_x, x, reduction='sum')
#     KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
#     return BCE + KLD
def loss_function(reconstructed_x, x, mu, logvar):
    reconstructed_x = torch.sigmoid(reconstructed_x)  # Apply sigmoid activation
    BCE = nn.functional.binary_cross_entropy(reconstructed_x, x, reduction='sum')
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return BCE + KLD


# Create VAE instance and move it to the device
vae = VAE(latent_dim).to(device)

# Optimizer
optimizer = optim.Adam(vae.parameters(), lr=learning_rate)

# %% [markdown]
# ## Training Loop

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# %%
import datetime

# %%
start = datetime.datetime.now()

# %%
vae.train()

for epoch in range(epochs):
    total_loss = 0
    for batch_idx, data in enumerate(dataloader, 0):
        data = data[0].to(device)
        optimizer.zero_grad()
        reconstructed_data, mu, logvar = vae(data)
        loss = loss_function(reconstructed_data, data, mu, logvar)
        loss.backward()
        total_loss += loss.item()
        optimizer.step()

        if batch_idx % 100 == 0:
            print(f'Epoch [{epoch+1}/{epochs}], Batch [{batch_idx}/{len(dataloader)}], Loss: {loss.item():.4f}')

    average_loss = total_loss / len(dataloader.dataset)
    print(f'Epoch [{epoch+1}/{epochs}], Average Loss: {average_loss:.4f}')

    # Generate sample images at the end of each epoch
    with torch.no_grad():
        fixed_noise = torch.randn(batch_size, latent_dim).to(device)
        generated_images = vae.decoder(fixed_noise).cpu()
        save_image(generated_images, f'vae_generated_images/{expID}/epoch_{epoch+1}.png', nrow=int(batch_size ** 0.5), normalize=True)

print("Training complete!")
end = datetime.datetime.now()

# Save the trained model
torch.save(vae.state_dict(), f'{expID}.pth')
# Out:
# Epoch [1/50], Batch [0/994], Loss: 526529.2500
# Epoch [1/50], Batch [100/994], Loss: 359716.7500
# Epoch [1/50], Batch [200/994], Loss: 299379.2188
# Epoch [1/50], Batch [300/994], Loss: 324181.4688
# Epoch [1/50], Batch [400/994], Loss: 295479.5312
# Epoch [1/50], Batch [500/994], Loss: 315511.8750
# Epoch [1/50], Batch [600/994], Loss: 275474.0312
# Epoch [1/50], Batch [700/994], Loss: 302386.9375
# Epoch [1/50], Batch [800/994], Loss: 281103.4688
# Epoch [1/50], Batch [900/994], Loss: 317296.3750
# Epoch [1/50], Average Loss: 4777.5603
# Epoch [2/50], Batch [0/994], Loss: 307946.5938
# Epoch [2/50], Batch [100/994], Loss: 308657.7500
# Epoch [2/50], Batch [200/994], Loss: 295437.6562
# Epoch [2/50], Batch [300/994], Loss: 282769.5312
# Epoch [2/50], Batch [400/994], Loss: 290113.5625
# Epoch [2/50], Batch [500/994], Loss: 261373.2969
# Epoch [2/50], Batch [600/994], Loss: 284440.3125
# Epoch [2/50], Batch [700/994], Loss: 287446.5312
# Epoch [2/50], Batch [800/994], Loss: 293590.3438
# Epoch [2/50], Batch [900/994], Loss: 273821.4375
# Epoch [2/50], Average Loss: 4380.0122
# Epoch [3/50], Batch [0/994], Loss: 283921.0312
# Epoch [3/50], Batch [100/994], Loss: 276356.8750
# Epoch [3/50], Batch [200/994], Loss: 274547.5000
# Epoch [3/50], Batch [300/994], Loss: 273069.2188
# Epoch [3/50], Batch [400/994], Loss: 282789.5000
# Epoch [3/50], Batch [500/994], Loss: 299235.6250
# Epoch [3/50], Batch [600/994], Loss: 275913.0312
# Epoch [3/50], Batch [700/994], Loss: 266848.4062
# Epoch [3/50], Batch [800/994], Loss: 264085.3125
# Epoch [3/50], Batch [900/994], Loss: 283341.9688
# Epoch [3/50], Average Loss: 4301.7854
# Epoch [4/50], Batch [0/994], Loss: 292278.5625
# Epoch [4/50], Batch [100/994], Loss: 276029.6562
# Epoch [4/50], Batch [200/994], Loss: 256172.7031
# Epoch [4/50], Batch [300/994], Loss: 263984.8750
# Epoch [4/50], Batch [400/994], Loss: 263809.6250
# Epoch [4/50], Batch [500/994], Loss: 269120.8750
# Epoch [4/50], Batch [600/994], Loss: 280983.3438
# Epoch [4/50], Batch [700/994], Loss: 287139.5938
# Epoch [4/50], Batch [800/994], Loss: 255735.5938
# Epoch [4/50], Batch [900/994], Loss: 267229.8125
# Epoch [4/50], Average Loss: 4260.9620
# Epoch [5/50], Batch [0/994], Loss: 253010.6562
# Epoch [5/50], Batch [100/994], Loss: 243348.1250
# Epoch [5/50], Batch [200/994], Loss: 282109.8750
# Epoch [5/50], Batch [300/994], Loss: 264449.0000
# Epoch [5/50], Batch [400/994], Loss: 265904.2812
# Epoch [5/50], Batch [500/994], Loss: 274756.3750
# Epoch [5/50], Batch [600/994], Loss: 258816.9062
# Epoch [5/50], Batch [700/994], Loss: 260752.9531
# Epoch [5/50], Batch [800/994], Loss: 267942.5938
# Epoch [5/50], Batch [900/994], Loss: 263998.5000
# Epoch [5/50], Average Loss: 4234.2030
# Epoch [6/50], Batch [0/994], Loss: 288082.3750
# Epoch [6/50], Batch [100/994], Loss: 263177.5938
# Epoch [6/50], Batch [200/994], Loss: 262932.3438
# Epoch [6/50], Batch [300/994], Loss: 253785.6406
# Epoch [6/50], Batch [400/994], Loss: 297081.8438
# Epoch [6/50], Batch [500/994], Loss: 270437.5000
# Epoch [6/50], Batch [600/994], Loss: 263563.5938
# Epoch [6/50], Batch [700/994], Loss: 293454.5938
# Epoch [6/50], Batch [800/994], Loss: 272561.4688
# Epoch [6/50], Batch [900/994], Loss: 254739.3125
# Epoch [6/50], Average Loss: 4216.9918
# Epoch [7/50], Batch [0/994], Loss: 289219.0938
# Epoch [7/50], Batch [100/994], Loss: 288367.9688
# Epoch [7/50], Batch [200/994], Loss: 285584.5938
# Epoch [7/50], Batch [300/994], Loss: 259208.4219
# Epoch [7/50], Batch [400/994], Loss: 249973.1250
# Epoch [7/50], Batch [500/994], Loss: 269463.1875
# Epoch [7/50], Batch [600/994], Loss: 240926.4844
# Epoch [7/50], Batch [700/994], Loss: 263552.4062
# Epoch [7/50], Batch [800/994], Loss: 267795.2188
# Epoch [7/50], Batch [900/994], Loss: 318773.8438
# Epoch [7/50], Average Loss: 4204.6285
# Epoch [8/50], Batch [0/994], Loss: 251581.1406
# Epoch [8/50], Batch [100/994], Loss: 269568.5000
# Epoch [8/50], Batch [200/994], Loss: 237387.4688
# Epoch [8/50], Batch [300/994], Loss: 273489.0000
# Epoch [8/50], Batch [400/994], Loss: 291679.2188
# Epoch [8/50], Batch [500/994], Loss: 251145.6094
# Epoch [8/50], Batch [600/994], Loss: 260965.4688
# Epoch [8/50], Batch [700/994], Loss: 285139.0312
# Epoch [8/50], Batch [800/994], Loss: 285638.6875
# Epoch [8/50], Batch [900/994], Loss: 286602.6250
# Epoch [8/50], Average Loss: 4195.1742
# Epoch [9/50], Batch [0/994], Loss: 288371.0000
# Epoch [9/50], Batch [100/994], Loss: 267317.4688
# Epoch [9/50], Batch [200/994], Loss: 234958.4062
# Epoch [9/50], Batch [300/994], Loss: 254278.3438
# Epoch [9/50], Batch [400/994], Loss: 266667.0000
# Epoch [9/50], Batch [500/994], Loss: 251920.7812
# Epoch [9/50], Batch [600/994], Loss: 272869.6250
# Epoch [9/50], Batch [700/994], Loss: 273624.7500
# Epoch [9/50], Batch [800/994], Loss: 260082.7031
# Epoch [9/50], Batch [900/994], Loss: 277345.1875
# Epoch [9/50], Average Loss: 4188.1014
# Epoch [10/50], Batch [0/994], Loss: 216457.6875
# Epoch [10/50], Batch [100/994], Loss: 262299.0312
# Epoch [10/50], Batch [200/994], Loss: 274356.7188
# Epoch [10/50], Batch [300/994], Loss: 289726.4375
# Epoch [10/50], Batch [400/994], Loss: 271336.1875
# Epoch [10/50], Batch [500/994], Loss: 276319.4688
# Epoch [10/50], Batch [600/994], Loss: 255743.8438
# Epoch [10/50], Batch [700/994], Loss: 275833.4375
# Epoch [10/50], Batch [800/994], Loss: 265478.8750
# Epoch [10/50], Batch [900/994], Loss: 265208.2812
# Epoch [10/50], Average Loss: 4182.0728
# Epoch [11/50], Batch [0/994], Loss: 266008.5312
# Epoch [11/50], Batch [100/994], Loss: 269662.6250
# Epoch [11/50], Batch [200/994], Loss: 262596.3750
# Epoch [11/50], Batch [300/994], Loss: 272632.2500
# Epoch [11/50], Batch [400/994], Loss: 271518.5625
# Epoch [11/50], Batch [500/994], Loss: 262947.6250
# Epoch [11/50], Batch [600/994], Loss: 279340.3750
# Epoch [11/50], Batch [700/994], Loss: 280468.7812
# Epoch [11/50], Batch [800/994], Loss: 262478.0938
# Epoch [11/50], Batch [900/994], Loss: 274743.0000
# Epoch [11/50], Average Loss: 4177.0148
# Epoch [12/50], Batch [0/994], Loss: 264064.7500
# Epoch [12/50], Batch [100/994], Loss: 276523.7188
# Epoch [12/50], Batch [200/994], Loss: 283414.6250
# Epoch [12/50], Batch [300/994], Loss: 272188.2500
# Epoch [12/50], Batch [400/994], Loss: 260652.0469
# Epoch [12/50], Batch [500/994], Loss: 255076.4531
# Epoch [12/50], Batch [600/994], Loss: 259399.1562
# Epoch [12/50], Batch [700/994], Loss: 250799.8750
# Epoch [12/50], Batch [800/994], Loss: 283408.2500
# Epoch [12/50], Batch [900/994], Loss: 278729.2188
# Epoch [12/50], Average Loss: 4172.9667
# Epoch [13/50], Batch [0/994], Loss: 279244.3125
# Epoch [13/50], Batch [100/994], Loss: 294028.2500
# Epoch [13/50], Batch [200/994], Loss: 254542.2344
# Epoch [13/50], Batch [300/994], Loss: 285974.3750
# Epoch [13/50], Batch [400/994], Loss: 270616.0312
# Epoch [13/50], Batch [500/994], Loss: 261280.3125
# Epoch [13/50], Batch [600/994], Loss: 263936.6250
# Epoch [13/50], Batch [700/994], Loss: 255370.0469
# Epoch [13/50], Batch [800/994], Loss: 278500.5625
# Epoch [13/50], Batch [900/994], Loss: 289917.3125
# Epoch [13/50], Average Loss: 4169.2635
# Epoch [14/50], Batch [0/994], Loss: 260523.9531
# Epoch [14/50], Batch [100/994], Loss: 278760.8750
# Epoch [14/50], Batch [200/994], Loss: 244558.0625
# Epoch [14/50], Batch [300/994], Loss: 280037.5000
# Epoch [14/50], Batch [400/994], Loss: 286232.8750
# Epoch [14/50], Batch [500/994], Loss: 280413.1250
# Epoch [14/50], Batch [600/994], Loss: 255743.2812
# Epoch [14/50], Batch [700/994], Loss: 277174.8750
# Epoch [14/50], Batch [800/994], Loss: 269020.2812
# Epoch [14/50], Batch [900/994], Loss: 270388.9375
# Epoch [14/50], Average Loss: 4165.9025
# Epoch [15/50], Batch [0/994], Loss: 290106.4062
# Epoch [15/50], Batch [100/994], Loss: 269929.0938
# Epoch [15/50], Batch [200/994], Loss: 258846.8281
# Epoch [15/50], Batch [300/994], Loss: 262225.4688
# Epoch [15/50], Batch [400/994], Loss: 265246.7812
# Epoch [15/50], Batch [500/994], Loss: 262194.5625
# Epoch [15/50], Batch [600/994], Loss: 257012.8594
# Epoch [15/50], Batch [700/994], Loss: 273810.3750
# Epoch [15/50], Batch [800/994], Loss: 261767.2188
# Epoch [15/50], Batch [900/994], Loss: 244402.4219
# Epoch [15/50], Average Loss: 4162.9508
# Epoch [16/50], Batch [0/994], Loss: 258667.3750
# Epoch [16/50], Batch [100/994], Loss: 255079.1250
# Epoch [16/50], Batch [200/994], Loss: 263149.5625
# Epoch [16/50], Batch [300/994], Loss: 279951.1875
# Epoch [16/50], Batch [400/994], Loss: 262188.5625
# Epoch [16/50], Batch [500/994], Loss: 254830.1719
# Epoch [16/50], Batch [600/994], Loss: 275960.9688
# Epoch [16/50], Batch [700/994], Loss: 276468.0312
# Epoch [16/50], Batch [800/994], Loss: 264896.5938
# Epoch [16/50], Batch [900/994], Loss: 257904.4531
# Epoch [16/50], Average Loss: 4160.3305
# Epoch [17/50], Batch [0/994], Loss: 257395.5469
# Epoch [17/50], Batch [100/994], Loss: 287427.9688
# Epoch [17/50], Batch [200/994], Loss: 237537.0625
# Epoch [17/50], Batch [300/994], Loss: 267944.2500
# Epoch [17/50], Batch [400/994], Loss: 282168.3750
# Epoch [17/50], Batch [500/994], Loss: 270157.0625
# Epoch [17/50], Batch [600/994], Loss: 269149.0312
# Epoch [17/50], Batch [700/994], Loss: 265424.4375
# Epoch [17/50], Batch [800/994], Loss: 273793.5938
# Epoch [17/50], Batch [900/994], Loss: 257868.5000
# Epoch [17/50], Average Loss: 4158.0007
# Epoch [18/50], Batch [0/994], Loss: 242735.0469
# Epoch [18/50], Batch [100/994], Loss: 255782.4219
# Epoch [18/50], Batch [200/994], Loss: 264886.8125
# Epoch [18/50], Batch [300/994], Loss: 280761.4062
# Epoch [18/50], Batch [400/994], Loss: 247145.2188
# Epoch [18/50], Batch [500/994], Loss: 263096.0938
# Epoch [18/50], Batch [600/994], Loss: 260228.5469
# Epoch [18/50], Batch [700/994], Loss: 253201.8438
# Epoch [18/50], Batch [800/994], Loss: 264940.8125
# Epoch [18/50], Batch [900/994], Loss: 270764.4375
# Epoch [18/50], Average Loss: 4155.3031
# Epoch [19/50], Batch [0/994], Loss: 245050.3125
# Epoch [19/50], Batch [100/994], Loss: 249326.7188
# Epoch [19/50], Batch [200/994], Loss: 268422.5938
# Epoch [19/50], Batch [300/994], Loss: 266094.1562
# Epoch [19/50], Batch [400/994], Loss: 250077.5156
# Epoch [19/50], Batch [500/994], Loss: 270243.1875
# Epoch [19/50], Batch [600/994], Loss: 260552.2031
# Epoch [19/50], Batch [700/994], Loss: 293301.7188
# Epoch [19/50], Batch [800/994], Loss: 246740.4375
# Epoch [19/50], Batch [900/994], Loss: 252154.7500
# Epoch [19/50], Average Loss: 4153.5577
# Epoch [20/50], Batch [0/994], Loss: 289420.5938
# Epoch [20/50], Batch [100/994], Loss: 263084.9375
# Epoch [20/50], Batch [200/994], Loss: 261874.2031
# Epoch [20/50], Batch [300/994], Loss: 256492.6406
# Epoch [20/50], Batch [400/994], Loss: 261063.5312
# Epoch [20/50], Batch [500/994], Loss: 255047.0781
# Epoch [20/50], Batch [600/994], Loss: 263488.2500
# Epoch [20/50], Batch [700/994], Loss: 258742.0469
# Epoch [20/50], Batch [800/994], Loss: 217806.9531
# Epoch [20/50], Batch [900/994], Loss: 268314.0625
# Epoch [20/50], Average Loss: 4151.5845
# Epoch [21/50], Batch [0/994], Loss: 264274.3438
# Epoch [21/50], Batch [100/994], Loss: 290730.5000
# Epoch [21/50], Batch [200/994], Loss: 255279.1094
# Epoch [21/50], Batch [300/994], Loss: 258167.3750
# Epoch [21/50], Batch [400/994], Loss: 268233.1562
# Epoch [21/50], Batch [500/994], Loss: 261915.8125
# Epoch [21/50], Batch [600/994], Loss: 281624.6250
# Epoch [21/50], Batch [700/994], Loss: 277680.5000
# Epoch [21/50], Batch [800/994], Loss: 293551.5938
# Epoch [21/50], Batch [900/994], Loss: 248721.3906
# Epoch [21/50], Average Loss: 4149.8044
# Epoch [22/50], Batch [0/994], Loss: 243308.6250
# Epoch [22/50], Batch [100/994], Loss: 254342.0312
# Epoch [22/50], Batch [200/994], Loss: 294228.8438
# Epoch [22/50], Batch [300/994], Loss: 281648.8438
# Epoch [22/50], Batch [400/994], Loss: 262505.5000
# Epoch [22/50], Batch [500/994], Loss: 272838.9062
# Epoch [22/50], Batch [600/994], Loss: 253295.8594
# Epoch [22/50], Batch [700/994], Loss: 273111.8750
# Epoch [22/50], Batch [800/994], Loss: 265966.9062
# Epoch [22/50], Batch [900/994], Loss: 262225.9062
# Epoch [22/50], Average Loss: 4147.9747
# Epoch [23/50], Batch [0/994], Loss: 276691.4062
# Epoch [23/50], Batch [100/994], Loss: 279546.4688
# Epoch [23/50], Batch [200/994], Loss: 272827.0938
# Epoch [23/50], Batch [300/994], Loss: 261975.5156
# Epoch [23/50], Batch [400/994], Loss: 247107.1719
# Epoch [23/50], Batch [500/994], Loss: 275082.2812
# Epoch [23/50], Batch [600/994], Loss: 274156.4375
# Epoch [23/50], Batch [700/994], Loss: 254407.7969
# Epoch [23/50], Batch [800/994], Loss: 265615.2500
# Epoch [23/50], Batch [900/994], Loss: 251066.6406
# Epoch [23/50], Average Loss: 4146.6047
# Epoch [24/50], Batch [0/994], Loss: 273970.1875
# Epoch [24/50], Batch [100/994], Loss: 283261.3438
# Epoch [24/50], Batch [200/994], Loss: 250609.6250
# Epoch [24/50], Batch [300/994], Loss: 263159.7188
# Epoch [24/50], Batch [400/994], Loss: 301005.2500
# Epoch [24/50], Batch [500/994], Loss: 267023.0000
# Epoch [24/50], Batch [600/994], Loss: 263859.0312
# Epoch [24/50], Batch [700/994], Loss: 269886.8125
# Epoch [24/50], Batch [800/994], Loss: 251312.4219
# Epoch [24/50], Batch [900/994], Loss: 259258.6094
# Epoch [24/50], Average Loss: 4144.7917
# Epoch [25/50], Batch [0/994], Loss: 283198.5625
# Epoch [25/50], Batch [100/994], Loss: 260409.5625
# Epoch [25/50], Batch [200/994], Loss: 267682.8750
# Epoch [25/50], Batch [300/994], Loss: 270438.2500
# Epoch [25/50], Batch [400/994], Loss: 242177.5625
# Epoch [25/50], Batch [500/994], Loss: 260714.1719
# Epoch [25/50], Batch [600/994], Loss: 253366.6406
# Epoch [25/50], Batch [700/994], Loss: 276530.5625
# Epoch [25/50], Batch [800/994], Loss: 255141.9531
# Epoch [25/50], Batch [900/994], Loss: 261908.0781
# Epoch [25/50], Average Loss: 4143.5350
# Epoch [26/50], Batch [0/994], Loss: 272380.3125
# Epoch [26/50], Batch [100/994], Loss: 245290.3750
# Epoch [26/50], Batch [200/994], Loss: 264929.7188
# Epoch [26/50], Batch [300/994], Loss: 260878.7500
# Epoch [26/50], Batch [400/994], Loss: 245430.4062
# Epoch [26/50], Batch [500/994], Loss: 252783.5781
# Epoch [26/50], Batch [600/994], Loss: 293769.0938
# Epoch [26/50], Batch [700/994], Loss: 261397.5938
# Epoch [26/50], Batch [800/994], Loss: 271913.8438
# Epoch [26/50], Batch [900/994], Loss: 250838.5000
# Epoch [26/50], Average Loss: 4142.3477
# Epoch [27/50], Batch [0/994], Loss: 268262.4062
# Epoch [27/50], Batch [100/994], Loss: 256287.1719
# Epoch [27/50], Batch [200/994], Loss: 256597.9219
# Epoch [27/50], Batch [300/994], Loss: 248475.4688
# Epoch [27/50], Batch [400/994], Loss: 274317.7500
# Epoch [27/50], Batch [500/994], Loss: 278003.7188
# Epoch [27/50], Batch [600/994], Loss: 265971.7812
# Epoch [27/50], Batch [700/994], Loss: 258341.3750
# Epoch [27/50], Batch [800/994], Loss: 286544.1875
# Epoch [27/50], Batch [900/994], Loss: 239049.6562
# Epoch [27/50], Average Loss: 4141.0246
# Epoch [28/50], Batch [0/994], Loss: 273039.5938
# Epoch [28/50], Batch [100/994], Loss: 256968.3906
# Epoch [28/50], Batch [200/994], Loss: 254284.7656
# Epoch [28/50], Batch [300/994], Loss: 263808.4688
# Epoch [28/50], Batch [400/994], Loss: 258248.0000
# Epoch [28/50], Batch [500/994], Loss: 255768.8594
# Epoch [28/50], Batch [600/994], Loss: 254615.7656
# Epoch [28/50], Batch [700/994], Loss: 270764.6250
# Epoch [28/50], Batch [800/994], Loss: 264415.0312
# Epoch [28/50], Batch [900/994], Loss: 281224.8438
# Epoch [28/50], Average Loss: 4139.7351
# Epoch [29/50], Batch [0/994], Loss: 260379.4062
# Epoch [29/50], Batch [100/994], Loss: 268204.2500
# Epoch [29/50], Batch [200/994], Loss: 258440.1250
# Epoch [29/50], Batch [300/994], Loss: 268714.4062
# Epoch [29/50], Batch [400/994], Loss: 281312.6875
# Epoch [29/50], Batch [500/994], Loss: 261269.5625
# Epoch [29/50], Batch [600/994], Loss: 248621.5156
# Epoch [29/50], Batch [700/994], Loss: 254334.9219
# Epoch [29/50], Batch [800/994], Loss: 275073.2188
# Epoch [29/50], Batch [900/994], Loss: 237684.4375
# Epoch [29/50], Average Loss: 4138.7691
# Epoch [30/50], Batch [0/994], Loss: 267109.9688
# Epoch [30/50], Batch [100/994], Loss: 261514.9531
# Epoch [30/50], Batch [200/994], Loss: 255618.9219
# Epoch [30/50], Batch [300/994], Loss: 264062.2188
# Epoch [30/50], Batch [400/994], Loss: 260740.0000
# Epoch [30/50], Batch [500/994], Loss: 233621.0312
# Epoch [30/50], Batch [600/994], Loss: 275157.3750
# Epoch [30/50], Batch [700/994], Loss: 286904.6250
# Epoch [30/50], Batch [800/994], Loss: 269527.0312
# Epoch [30/50], Batch [900/994], Loss: 277533.8438
# Epoch [30/50], Average Loss: 4137.9016
# Epoch [31/50], Batch [0/994], Loss: 252343.8281
# Epoch [31/50], Batch [100/994], Loss: 290490.5312
# Epoch [31/50], Batch [200/994], Loss: 249978.7500
# Epoch [31/50], Batch [300/994], Loss: 257701.8594
# Epoch [31/50], Batch [400/994], Loss: 257043.0938
# Epoch [31/50], Batch [500/994], Loss: 259452.8125
# Epoch [31/50], Batch [600/994], Loss: 258907.6719
# Epoch [31/50], Batch [700/994], Loss: 283822.5312
# Epoch [31/50], Batch [800/994], Loss: 258292.5000
# Epoch [31/50], Batch [900/994], Loss: 266231.6250
# Epoch [31/50], Average Loss: 4136.5323
# Epoch [32/50], Batch [0/994], Loss: 271884.3438
# Epoch [32/50], Batch [100/994], Loss: 268177.2188
# Epoch [32/50], Batch [200/994], Loss: 276627.1875
# Epoch [32/50], Batch [300/994], Loss: 265502.8750
# Epoch [32/50], Batch [400/994], Loss: 264344.2812
# Epoch [32/50], Batch [500/994], Loss: 268244.4062
# Epoch [32/50], Batch [600/994], Loss: 270458.5000
# Epoch [32/50], Batch [700/994], Loss: 276404.9062
# Epoch [32/50], Batch [800/994], Loss: 250207.7812
# Epoch [32/50], Batch [900/994], Loss: 265596.4062
# Epoch [32/50], Average Loss: 4135.7838
# Epoch [33/50], Batch [0/994], Loss: 279208.9688
# Epoch [33/50], Batch [100/994], Loss: 266203.0312
# Epoch [33/50], Batch [200/994], Loss: 273243.5625
# Epoch [33/50], Batch [300/994], Loss: 268108.1250
# Epoch [33/50], Batch [400/994], Loss: 240491.2031
# Epoch [33/50], Batch [500/994], Loss: 279237.4062
# Epoch [33/50], Batch [600/994], Loss: 262178.3750
# Epoch [33/50], Batch [700/994], Loss: 273225.3438
# Epoch [33/50], Batch [800/994], Loss: 272913.0000
# Epoch [33/50], Batch [900/994], Loss: 264874.9375
# Epoch [33/50], Average Loss: 4134.7432
# Epoch [34/50], Batch [0/994], Loss: 272368.5938
# Epoch [34/50], Batch [100/994], Loss: 284899.3750
# Epoch [34/50], Batch [200/994], Loss: 269276.0625
# Epoch [34/50], Batch [300/994], Loss: 264945.6250
# Epoch [34/50], Batch [400/994], Loss: 261484.5781
# Epoch [34/50], Batch [500/994], Loss: 261238.2031
# Epoch [34/50], Batch [600/994], Loss: 270230.4062
# Epoch [34/50], Batch [700/994], Loss: 277928.9062
# Epoch [34/50], Batch [800/994], Loss: 247228.3281
# Epoch [34/50], Batch [900/994], Loss: 251328.9844
# Epoch [34/50], Average Loss: 4133.9004
# Epoch [35/50], Batch [0/994], Loss: 254334.2656
# Epoch [35/50], Batch [100/994], Loss: 272831.2500
# Epoch [35/50], Batch [200/994], Loss: 281774.7188
# Epoch [35/50], Batch [300/994], Loss: 255252.9688
# Epoch [35/50], Batch [400/994], Loss: 263653.9375
# Epoch [35/50], Batch [500/994], Loss: 258465.8125
# Epoch [35/50], Batch [600/994], Loss: 244481.8750
# Epoch [35/50], Batch [700/994], Loss: 274680.4062
# Epoch [35/50], Batch [800/994], Loss: 262388.4062
# Epoch [35/50], Batch [900/994], Loss: 247011.0625
# Epoch [35/50], Average Loss: 4132.9405
# Epoch [36/50], Batch [0/994], Loss: 266704.5625
# Epoch [36/50], Batch [100/994], Loss: 291027.2500
# Epoch [36/50], Batch [200/994], Loss: 258224.9531
# Epoch [36/50], Batch [300/994], Loss: 280069.5625
# Epoch [36/50], Batch [400/994], Loss: 250215.2031
# Epoch [36/50], Batch [500/994], Loss: 274898.4688
# Epoch [36/50], Batch [600/994], Loss: 265855.4688
# Epoch [36/50], Batch [700/994], Loss: 266613.2500
# Epoch [36/50], Batch [800/994], Loss: 253553.5938
# Epoch [36/50], Batch [900/994], Loss: 247569.6094
# Epoch [36/50], Average Loss: 4132.0982
# Epoch [37/50], Batch [0/994], Loss: 291780.2500
# Epoch [37/50], Batch [100/994], Loss: 283467.5938
# Epoch [37/50], Batch [200/994], Loss: 250485.9375
# Epoch [37/50], Batch [300/994], Loss: 276828.9688
# Epoch [37/50], Batch [400/994], Loss: 245917.5156
# Epoch [37/50], Batch [500/994], Loss: 269806.2188
# Epoch [37/50], Batch [600/994], Loss: 257767.2188
# Epoch [37/50], Batch [700/994], Loss: 264078.4062
# Epoch [37/50], Batch [800/994], Loss: 256635.3438
# Epoch [37/50], Batch [900/994], Loss: 273175.5625
# Epoch [37/50], Average Loss: 4131.2106
# Epoch [38/50], Batch [0/994], Loss: 269867.7500
# Epoch [38/50], Batch [100/994], Loss: 284572.1875
# Epoch [38/50], Batch [200/994], Loss: 247957.2031
# Epoch [38/50], Batch [300/994], Loss: 240592.1562
# Epoch [38/50], Batch [400/994], Loss: 260207.1719
# Epoch [38/50], Batch [500/994], Loss: 242165.7656
# Epoch [38/50], Batch [600/994], Loss: 270648.4062
# Epoch [38/50], Batch [700/994], Loss: 273709.9062
# Epoch [38/50], Batch [800/994], Loss: 254911.0781
# Epoch [38/50], Batch [900/994], Loss: 258700.8125
# Epoch [38/50], Average Loss: 4130.6618
# Epoch [39/50], Batch [0/994], Loss: 258315.3906
# Epoch [39/50], Batch [100/994], Loss: 276778.6250
# Epoch [39/50], Batch [200/994], Loss: 260610.5781
# Epoch [39/50], Batch [300/994], Loss: 281869.4688
# Epoch [39/50], Batch [400/994], Loss: 267027.2812
# Epoch [39/50], Batch [500/994], Loss: 272578.8750
# Epoch [39/50], Batch [600/994], Loss: 257342.2031
# Epoch [39/50], Batch [700/994], Loss: 266386.2188
# Epoch [39/50], Batch [800/994], Loss: 246953.9375
# Epoch [39/50], Batch [900/994], Loss: 258339.9531
# Epoch [39/50], Average Loss: 4129.7430
# Epoch [40/50], Batch [0/994], Loss: 269804.5625
# Epoch [40/50], Batch [100/994], Loss: 266203.2188
# Epoch [40/50], Batch [200/994], Loss: 273219.4062
# Epoch [40/50], Batch [300/994], Loss: 253169.5625
# Epoch [40/50], Batch [400/994], Loss: 248836.6406
# Epoch [40/50], Batch [500/994], Loss: 281866.6562
# Epoch [40/50], Batch [600/994], Loss: 264064.4062
# Epoch [40/50], Batch [700/994], Loss: 260924.5469
# Epoch [40/50], Batch [800/994], Loss: 279394.7812
# Epoch [40/50], Batch [900/994], Loss: 288528.9375
# Epoch [40/50], Average Loss: 4129.0064
# Epoch [41/50], Batch [0/994], Loss: 284209.0000
# Epoch [41/50], Batch [100/994], Loss: 249108.3906
# Epoch [41/50], Batch [200/994], Loss: 285355.4375
# Epoch [41/50], Batch [300/994], Loss: 257158.3125
# Epoch [41/50], Batch [400/994], Loss: 245885.8438
# Epoch [41/50], Batch [500/994], Loss: 294466.2812
# Epoch [41/50], Batch [600/994], Loss: 274267.0312
# Epoch [41/50], Batch [700/994], Loss: 260745.7812
# Epoch [41/50], Batch [800/994], Loss: 277211.1562
# Epoch [41/50], Batch [900/994], Loss: 266187.7188
# Epoch [41/50], Average Loss: 4128.2679
# Epoch [42/50], Batch [0/994], Loss: 267752.4062
# Epoch [42/50], Batch [100/994], Loss: 260290.9531
# Epoch [42/50], Batch [200/994], Loss: 252981.6094
# Epoch [42/50], Batch [300/994], Loss: 254405.1875
# Epoch [42/50], Batch [400/994], Loss: 245603.9062
# Epoch [42/50], Batch [500/994], Loss: 276343.2188
# Epoch [42/50], Batch [600/994], Loss: 270647.4375
# Epoch [42/50], Batch [700/994], Loss: 245298.4531
# Epoch [42/50], Batch [800/994], Loss: 255963.5156
# Epoch [42/50], Batch [900/994], Loss: 281972.6875
# Epoch [42/50], Average Loss: 4127.7062
# Epoch [43/50], Batch [0/994], Loss: 253610.2812
# Epoch [43/50], Batch [100/994], Loss: 277334.7500
# Epoch [43/50], Batch [200/994], Loss: 279042.4062
# Epoch [43/50], Batch [300/994], Loss: 266053.7812
# Epoch [43/50], Batch [400/994], Loss: 242324.8125
# Epoch [43/50], Batch [500/994], Loss: 254226.4844
# Epoch [43/50], Batch [600/994], Loss: 255835.7500
# Epoch [43/50], Batch [700/994], Loss: 282366.1875
# Epoch [43/50], Batch [800/994], Loss: 288642.2812
# Epoch [43/50], Batch [900/994], Loss: 260440.9531
# Epoch [43/50], Average Loss: 4126.8584
# Epoch [44/50], Batch [0/994], Loss: 258272.6250
# Epoch [44/50], Batch [100/994], Loss: 239295.8438
# Epoch [44/50], Batch [200/994], Loss: 271574.6250
# Epoch [44/50], Batch [300/994], Loss: 251280.1875
# Epoch [44/50], Batch [400/994], Loss: 265243.9062
# Epoch [44/50], Batch [500/994], Loss: 255260.6719
# Epoch [44/50], Batch [600/994], Loss: 287170.4375
# Epoch [44/50], Batch [700/994], Loss: 251466.1094
# Epoch [44/50], Batch [800/994], Loss: 249366.1250
# Epoch [44/50], Batch [900/994], Loss: 272647.1562
# Epoch [44/50], Average Loss: 4126.3302
# Epoch [45/50], Batch [0/994], Loss: 270101.1875
# Epoch [45/50], Batch [100/994], Loss: 250949.6094
# Epoch [45/50], Batch [200/994], Loss: 254980.1094
# Epoch [45/50], Batch [300/994], Loss: 249259.0469
# Epoch [45/50], Batch [400/994], Loss: 254915.0312
# Epoch [45/50], Batch [500/994], Loss: 266947.0312
# Epoch [45/50], Batch [600/994], Loss: 283016.0938
# Epoch [45/50], Batch [700/994], Loss: 274323.2500
# Epoch [45/50], Batch [800/994], Loss: 258091.4219
# Epoch [45/50], Batch [900/994], Loss: 279050.2812
# Epoch [45/50], Average Loss: 4125.6820
# Epoch [46/50], Batch [0/994], Loss: 260541.2344
# Epoch [46/50], Batch [100/994], Loss: 259274.8281
# Epoch [46/50], Batch [200/994], Loss: 279694.0000
# Epoch [46/50], Batch [300/994], Loss: 255082.9062
# Epoch [46/50], Batch [400/994], Loss: 268606.0312
# Epoch [46/50], Batch [500/994], Loss: 267077.1250
# Epoch [46/50], Batch [600/994], Loss: 271463.5625
# Epoch [46/50], Batch [700/994], Loss: 268585.9688
# Epoch [46/50], Batch [800/994], Loss: 271079.9688
# Epoch [46/50], Batch [900/994], Loss: 270529.5938
# Epoch [46/50], Average Loss: 4124.8885
# Epoch [47/50], Batch [0/994], Loss: 267620.3438
# Epoch [47/50], Batch [100/994], Loss: 262303.7188
# Epoch [47/50], Batch [200/994], Loss: 264091.0938
# Epoch [47/50], Batch [300/994], Loss: 255551.0781
# Epoch [47/50], Batch [400/994], Loss: 252976.4219
# Epoch [47/50], Batch [500/994], Loss: 219722.5938
# Epoch [47/50], Batch [600/994], Loss: 241084.0156
# Epoch [47/50], Batch [700/994], Loss: 287262.1250
# Epoch [47/50], Batch [800/994], Loss: 274019.0938
# Epoch [47/50], Batch [900/994], Loss: 267961.8125
# Epoch [47/50], Average Loss: 4124.5598
# Epoch [48/50], Batch [0/994], Loss: 242743.1875
# Epoch [48/50], Batch [100/994], Loss: 261054.1562
# Epoch [48/50], Batch [200/994], Loss: 259671.9844
# Epoch [48/50], Batch [300/994], Loss: 266190.7812
# Epoch [48/50], Batch [400/994], Loss: 249219.7500
# Epoch [48/50], Batch [500/994], Loss: 270705.6875
# Epoch [48/50], Batch [600/994], Loss: 242137.5938
# Epoch [48/50], Batch [700/994], Loss: 292339.1562
# Epoch [48/50], Batch [800/994], Loss: 266605.6562
# Epoch [48/50], Batch [900/994], Loss: 279234.4062
# Epoch [48/50], Average Loss: 4123.7118
# Epoch [49/50], Batch [0/994], Loss: 237910.7188
# Epoch [49/50], Batch [100/994], Loss: 260821.2500
# Epoch [49/50], Batch [200/994], Loss: 239075.3594
# Epoch [49/50], Batch [300/994], Loss: 285410.7188
# Epoch [49/50], Batch [400/994], Loss: 260103.7812
# Epoch [49/50], Batch [500/994], Loss: 265099.7500
# Epoch [49/50], Batch [600/994], Loss: 258280.7188
# Epoch [49/50], Batch [700/994], Loss: 243605.8281
# Epoch [49/50], Batch [800/994], Loss: 256610.0625
# Epoch [49/50], Batch [900/994], Loss: 244263.6875
# Epoch [49/50], Average Loss: 4123.3442
# Epoch [50/50], Batch [0/994], Loss: 266119.3125
# Epoch [50/50], Batch [100/994], Loss: 259588.5156
# Epoch [50/50], Batch [200/994], Loss: 264847.4375
# Epoch [50/50], Batch [300/994], Loss: 275347.1562
# Epoch [50/50], Batch [400/994], Loss: 284143.7812
# Epoch [50/50], Batch [500/994], Loss: 254454.3438
# Epoch [50/50], Batch [600/994], Loss: 250058.0312
# Epoch [50/50], Batch [700/994], Loss: 250935.2188
# Epoch [50/50], Batch [800/994], Loss: 264967.1250
# Epoch [50/50], Batch [900/994], Loss: 263096.3750
# Epoch [50/50], Average Loss: 4122.7275
# Training complete!

# %%
print(start, end)
# Out:
# 2023-05-20 13:44:07.729202 2023-05-20 14:01:49.674692

# %%
print(torch.cuda.is_available())
print(torch.cuda.get_device_name())
# Out:
# True
# NVIDIA GeForce RTX 3060 Laptop GPU

# %%
loaded = VAE(latent_dim).to(device)
loaded.load_state_dict(torch.load(f'{expID}.pth'))
# Out:
# <All keys matched successfully>

# %%
loaded
# Out:
# VAE(
#   (encoder): Encoder(
#     (conv): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (3): ReLU()
#       (4): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (5): ReLU()
#       (6): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (7): ReLU()
#     )
#     (fc_mu): Linear(in_features=4096, out_features=100, bias=True)
#     (fc_logvar): Linear(in_features=4096, out_features=100, bias=True)
#   )
#   (decoder): Decoder(
#     (fc): Sequential(
#       (0): Linear(in_features=100, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=4096, bias=True)
#       (3): ReLU()
#     )
#     (deconv): Sequential(
#       (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): ReLU()
#       (2): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (3): ReLU()
#       (4): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (5): ReLU()
#       (6): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (7): Tanh()
#     )
#   )
# )

# %%
with torch.no_grad():
    fixed_noise = torch.randn(1, latent_dim).to(device)
    img = loaded.decoder(fixed_noise).cpu()

# %%
fake_img = vutils.make_grid(img, padding=2, normalize=True)
transposed = np.transpose(vutils.make_grid(fake_img, padding=5, normalize=True).cpu(),(1,2,0))
plt.imshow(transposed)
plt.axis('off')
# Out:
# (-0.5, 63.5, 63.5, -0.5)
